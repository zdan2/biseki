# %%
import sympy

# %%
#31
x=sympy.Symbol('x')
sympy.integrate(3*x**2-2*x+1)
# Out:
# x**3 - x**2 + x

# %%
#32
sympy.integrate(sympy.exp(x))
# Out:
# exp(x)

# %%
sympy.integrate(2*sympy.exp(x))
# Out:
# 2*exp(x)

# %%
#33
sindx=sympy.integrate(sympy.sin(x))
cosdx=sympy.integrate(sympy.cos(x))
secdx=sympy.integrate((sympy.sec(x))**2)
print(sindx,cosdx,secdx)
# Out:
# -cos(x) sin(x) sin(x)/cos(x)

# %%
#34
sympy.integrate(2*x*sympy.exp(x**2))
# Out:
# exp(x**2)

# %%
#35
sympy.integrate(x*sympy.sin(x))
# Out:
# -x*cos(x) + sin(x)

# %%
#36
sympy.integrate(x*sympy.exp(x))
# Out:
# (x - 1)*exp(x)

# %%
#37
sympy.integrate((x**2+1),(x,0,2))
# Out:
# 14/3

# %%
#38
sympy.integrate(sympy.exp(x),(x,0,1))
# Out:
# -1 + E

# %%
#39
sympy.integrate(sympy.sin(x),(x,0,sympy.pi))
# Out:
# 2

# %%
#40
print(sympy.integrate(1/(x**2)))
sympy.integrate(1/(x**2),(x,1,float('inf')))
# Out:
# -1/x
# 1
